# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rcParams['font.sans-serif']=['SimHei']#设置字体样式以正常显示中文
mpl.rcParams['axes.unicode_minus'] = False#使用Unicode格式的负号

# %%
df = pd.read_csv('merged_sentiment_idx.csv')
df.head()
# Out:
#   created_time        BI  BI_Simple     open     high      low    close  \
# 0   2020-10-17  0.319064   0.159091      NaN      NaN      NaN      NaN
# 1   2020-10-18  0.328685   0.163498      NaN      NaN      NaN      NaN
# 2   2020-10-19 -0.302835  -0.150339  3351.10  3371.09  3307.84  3312.67
# 3   2020-10-20 -0.175275  -0.087477  3307.15  3328.10  3293.77  3328.10
# 4   2020-10-21 -0.268797  -0.133661  3332.15  3332.15  3304.17  3325.02
#
#          volume  BI_MA  BI_Simple_MA
# 0           NaN    NaN           NaN
# 1           NaN    NaN           NaN
# 2  2.123035e+10    NaN           NaN
# 3  1.650848e+10    NaN           NaN
# 4  1.776321e+10    NaN           NaN

# %%
df = pd.read_csv('merged_sentiment_idx.csv')
df['created_time']=pd.to_datetime(df['created_time'])
df.set_index(df.created_time, inplace=True)
#df=df.dropna()
df.head()
# Out:
#              created_time        BI  BI_Simple     open     high      low  \
# created_time
# 2020-10-17     2020-10-17  0.319064   0.159091      NaN      NaN      NaN
# 2020-10-18     2020-10-18  0.328685   0.163498      NaN      NaN      NaN
# 2020-10-19     2020-10-19 -0.302835  -0.150339  3351.10  3371.09  3307.84
# 2020-10-20     2020-10-20 -0.175275  -0.087477  3307.15  3328.10  3293.77
# 2020-10-21     2020-10-21 -0.268797  -0.133661  3332.15  3332.15  3304.17
#
#                 close        volume  BI_MA  BI_Simple_MA
# created_time
# 2020-10-17        NaN           NaN    NaN           NaN
# 2020-10-18        NaN           NaN    NaN           NaN
# 2020-10-19    3312.67  2.123035e+10    NaN           NaN
# 2020-10-20    3328.10  1.650848e+10    NaN           NaN
# 2020-10-21    3325.02  1.776321e+10    NaN           NaN

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()#产生一个ax1的镜面坐标作为次坐标轴
ax1.plot(df.index, df['BI_MA'], color='g', linestyle=':')
ax2.plot(df.index, df['close'], color='b')
ax1.set_xlabel('日期')
ax1.set_ylabel('BI指标')
ax2.set_ylabel('上证指数')

#plt.show()
plt.savefig('plot.png')
